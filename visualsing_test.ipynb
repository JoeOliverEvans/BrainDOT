# %% [markdown]
# ## Looking at the imaging volume

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import mat73
import scipy.io as sio
import scipy.ndimage
import scipy

# %%
img = sio.loadmat('Datasets/BiggerDatasetDeeper/CCW1_processed.mat')
img2 = mat73.loadmat('Datasets/CCW1/NeurodotSmoothImages.mat')

noisy_img = img['noisy_images']
recon_img = img['recon2']
clean_img = img2['noisy_images']

# %%
img = sio.loadmat('Datasets/BiggerDataset/test_processed.mat')
img2 = mat73.loadmat('Datasets/CCW1/NeurodotSmoothImages.mat')

noisy_img = img['noisy_images']
recon_img = img['recon2']
clean_img = img['smooth_images']

# %%
i=16

# %%
ax = plt.figure().add_subplot(projection='3d')
ax.voxels(abs(clean_img[:,:,:,i])>5, alpha=1)
ax.azim = 90

plt.show()

# %%
ax = plt.figure().add_subplot(projection='3d')
ax.voxels(abs(noisy_img[:,:,:,i])>5, alpha=1)
ax.azim=90


plt.show()

# %%
ax = plt.figure().add_subplot(projection='3d')
ax.voxels(abs(recon_img[:,:,:,i])>2, alpha=1)
ax.azim=90
plt.show()

# %%
j = 8
plt.imshow(-noisy_img[j,:,::-1,i].T, cmap='jet')
plt.colorbar()

# %%
plt.imshow(-recon_img[j,:,::-1,i].T, cmap='jet')

# %%
plt.imshow(-clean_img[j,:,::-1,i].T, cmap='jet')

# %%
recon_img.shape
# Out:
# (32, 80, 64, 36)

# %%
clean_img.shape
# Out:
# (32, 80, 64, 36)

# %%
noisy_img.shape
# Out:
# (32, 80, 64, 36)
